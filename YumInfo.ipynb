# %%
import pandas as pd
dy1 = pd.read_csv("/Users/noahschutz/Documents/yumstock.csv")
print(dy1)
# Out:
#             date   open     high      low  close  sharetrade Unnamed: 6
# 0     2013-02-08  63.70  65.4900  63.6600  65.30     7190051        YUM
# 1     2013-02-11  65.16  65.1900  64.4800  64.55     5352531        YUM
# 2     2013-02-12  64.58  65.0600  64.0600  64.75     4934311        YUM
# 3     2013-02-13  64.77  64.9100  63.9500  64.41     3999959        YUM
# 4     2013-02-14  64.27  64.5360  63.7700  63.89     3949356        YUM
# 5     2013-02-15  63.82  64.5000  63.4450  63.99     4334641        YUM
# 6     2013-02-19  64.20  65.1850  63.9300  65.15     4288462        YUM
# 7     2013-02-20  65.17  65.4600  64.5200  64.56     4302390        YUM
# 8     2013-02-21  64.27  65.4000  64.2500  65.05     4490422        YUM
# 9     2013-02-22  65.21  65.5960  64.7200  65.45     2579023        YUM
# 10    2013-02-25  65.62  66.3900  64.7300  64.73     4389162        YUM
# 11    2013-02-26  65.15  65.4800  64.3050  64.87     3758313        YUM
# ...

# %% [markdown]
# ## So we have our information, but now we want to narrow our information.

# %%
dy1
# Out:
#             date   open     high      low  close  sharetrade Unnamed: 6
# 0     2013-02-08  63.70  65.4900  63.6600  65.30     7190051        YUM
# 1     2013-02-11  65.16  65.1900  64.4800  64.55     5352531        YUM
# 2     2013-02-12  64.58  65.0600  64.0600  64.75     4934311        YUM
# 3     2013-02-13  64.77  64.9100  63.9500  64.41     3999959        YUM
# 4     2013-02-14  64.27  64.5360  63.7700  63.89     3949356        YUM
# 5     2013-02-15  63.82  64.5000  63.4450  63.99     4334641        YUM
# 6     2013-02-19  64.20  65.1850  63.9300  65.15     4288462        YUM
# 7     2013-02-20  65.17  65.4600  64.5200  64.56     4302390        YUM
# 8     2013-02-21  64.27  65.4000  64.2500  65.05     4490422        YUM
# 9     2013-02-22  65.21  65.5960  64.7200  65.45     2579023        YUM
# 10    2013-02-25  65.62  66.3900  64.7300  64.73     4389162        YUM
# 11    2013-02-26  65.15  65.4800  64.3050  64.87     3758313        YUM
# ...

# %%
dy1["close"].mean()
# Out:
# 75.45100873709283

# %% [markdown]
# ** This means that over the past 5+ years, YUM stock has been valued at about $75.45 in the markets. **

# %% [markdown]
# * Honestly though, this was the third dataset I tried to work, as the first two didn't really give any relevant information that I could talk about.
# * Regardless, for this one I can also develop a summary of the available data.

# %%
dy1.describe()
# Out:
#               open         high          low        close    sharetrade
# count  1259.000000  1259.000000  1259.000000  1259.000000  1.259000e+03
# mean     75.422099    76.027123    74.844914    75.451009  3.209032e+06
# std       7.488521     7.550618     7.427339     7.485003  2.217774e+06
# min      59.890000    60.250000    59.570000    59.700000  6.667050e+05
# 25%      70.435000    70.934950    69.665000    70.225000  1.973342e+06
# 50%      74.110000    74.610000    73.650000    74.100000  2.665015e+06
# 75%      80.380000    81.145000    79.620000    80.470000  3.710812e+06
# max      94.950000    95.900000    94.150000    94.880000  3.679555e+07

# %%
#can we properly search for a day that the stock opened at a particular value?
dy1["low"].count()
# Out:
# 1259

# %% [markdown]
# #### so there are 1259 dates we can search for

# %%
dy1["open"].index[82.15]
#this is where I've gotten a bit stuck, as I've tried multiple combinations of syntax to get this code to work, probably need another command other than index but idk
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-3983e811d0a8> in <module>()
# ----> 1 dy1["open"].index[82.15]
#       2 #this is where I've gotten a bit stuck, as I've tried multiple combinations of syntax to get this code to work, probably need another command other than index but idk
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/range.py in __getitem__(self, key)
#     498             n = int(key)
#     499             if n != key:
# --> 500                 return super_getitem(key)
#     501             if n < 0:
#     502                 n = len(self) + key
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    2067
#    2068         if is_scalar(key):
# -> 2069             return getitem(key)
#    2070
#    2071         if isinstance(key, slice):
#
# ...
